# %% [markdown]
# # 05 — Candidate Fit Predictor (Explainable Multi-Factor Model)
#
# Inspect the transparent fit prediction engine.
# Note: Because raw public datasets do not include hiring decision outcomes, this module implements an explainable multi-factor scoring algorithm rather than inventing synthetic binary labels.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.models.fit_predictor import compute_candidate_fit

sample_resume = "Experienced Machine Learning Engineer with Python, Scikit-learn, TensorFlow, SQL, and AWS."
sample_job = {
    "title": "Senior Data Scientist",
    "skills": "Python, SQL, Machine Learning, TensorFlow, PyTorch, Docker, Kubernetes",
    "description": "Looking for a Senior Data Scientist with expertise in ML, Python, and cloud deployments.",
}

fit_result = compute_candidate_fit(
    resume_text=sample_resume,
    job_info=sample_job,
    predicted_category="Data Science",
    semantic_similarity=0.48,
)

print(f"Overall Fit Score: {fit_result['fit_score']}/100 ({fit_result['fit_tier']})")
print(f"Summary: {fit_result['summary']}")
print("Score Breakdown:", fit_result["breakdown"])
print("Matched Skills:", fit_result["matched_skills"])
print("Missing Skills:", fit_result["missing_skills"])
