# %% [markdown]
# # 02 — Resume Classifier (Supervised Learning)
#
# Train a classical NLP model to classify resume text into 25 target job categories.
# - Feature extraction: TF-IDF with sublinear term-frequency scaling
# - Model: Multi-class Logistic Regression with class-weight balancing
# - Evaluation: Accuracy, Precision, Recall, Macro F1, Confusion Matrix

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.models.classifier import train_classifier, predict_category, load_classifier

# Train and evaluate classifier
results = train_classifier(save=True)
metrics = results["metrics"]

print(f"Test Accuracy:     {metrics['accuracy'] * 100:.2f}%")
print(f"Macro F1-Score:    {metrics['f1_macro']:.4f}")
print(f"Weighted F1-Score: {metrics['f1_weighted']:.4f}")

# %% [markdown]
# ## Test Single Resume Prediction

# %%
sample_resume = """
Data Scientist with hands-on experience in Python, Pandas, Scikit-learn, TensorFlow,
NLP, Machine Learning, Statistical Analysis, and SQL database querying.
"""
model, vectorizer = load_classifier()
prediction = predict_category(sample_resume, model, vectorizer)
print("Prediction Output:", prediction)
